# %% [markdown]
# # Marco - Markdown Practice

# %% [markdown]
# ### Hello, my name is Marco. I am interesting in coding because of a class I took last semester where we used Wolfram.

# %% [markdown]
# - Programming assinments
# - Quizzes
# - Attendance/In-Class participation
# - Mid-term Exam
# - Project

# %% [markdown]
# 1. Module 1: Variables, Simple Data Types, and Github Discussion
# 2. Module 2: Lits and Tuples Part 1
# 3. Module 3: If Statements
# 4. Module 4: Loops
# 5. Module 5: Lists and Tuples Part 2
# 6. Module 6: Dictionaries
# 7. Module 7: Sets, FUnctions, Libraries
# 8. Module 8: Class Datatypes and Exceptions
# 9. Module 9: NumPY Arrays
# 10. Module 10: Pandas and Files Excerp

# %% [markdown]
# Today I 'did my last final exam'.

# %% [markdown]
# **Python**

# %% [markdown]
# *Anaconda Toolbox*

# %% [markdown]
# [Link](https://github.com/IOUmoni-dev)

# %% [markdown]
# ![Bellarmine Logo](https://www.bellarmine.edu/_migrated-binaries/sf-images/default-source/marketing/university-seal.png?sfvrsn=b6046380_0&MaxWidth=300&MaxHeight=202&ScaleUp=false&Quality=High&Method=ResizeFitToAreaArguments&Signature=53151A141C39DAC46ECE7B86E0BE1C34)

# %% [markdown]
# In this Markdown practice, I learned how to create headers, bullet lists, numbered lists, bold text, italic text, inline code, hyperlinks, and images in a Jupyter Notebook.
